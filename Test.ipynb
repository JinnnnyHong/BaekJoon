# %%
! git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
print("Hello World")
# Out:
# Hello World

# %%
! git add .

! git commit -m "add file"

! git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
