# %%
L = []
K = []
for i in range(7):
  a = int(input())
  if a % 2 != 0:
    L.append(a)
  else:
    K.append(a)
if len(L) == 0:
  print(-1)
else:
  print(sum(L))
  print(min(L))
# Out:
# 12
# 77
# 38
# 41
# 53
# 92
# 85
# 256
# 41

# %%
! git init
# Out:
# Reinitialized existing Git repository in /content/.git/
